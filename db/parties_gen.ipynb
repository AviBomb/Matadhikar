# %%
import os, requests, uuid, json
from faker import Faker
from faker.providers import internet
import random
from pymongo import MongoClient 
from datetime import datetime, date
# import gridFS
from bson import objectid
from gridfs import GridFS
try:
    client = MongoClient("mongodb+srv://codefundo:codefundo@cluster0-qx5uu.azure.mongodb.net/test?retryWrites=true") 
    print(client)
    print("connection successfull!")
    # print(client)
except:
    print("connection not established")
db=client.get_database('codefundo')
records=db.parties
print(records.count_documents({}))
# Out:
# MongoClient(host=['cluster0-shard-00-02-qx5uu.azure.mongodb.net:27017', 'cluster0-shard-00-00-qx5uu.azure.mongodb.net:27017', 'cluster0-shard-00-01-qx5uu.azure.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Cluster0-shard-0', ssl=True, retrywrites=True)
# connection successfull!
# 0

# %%
import base64

# %%
import os
path = 'D:\\Documents\\codefundo++\\pics'
files = os.listdir(path)
i = 0
l=[]
for file in files:
    l.append(file)
print(l)
dic={}
# with open(request.GET["image_name"], "rb") as image_file:
#         encoded_string = base64.b64encode(image_file.read())
for file in files:
    with open(path+'\\'+file, "rb") as image_file:
        encoded_string = base64.b64encode(image_file.read())
        dic[file]=encoded_string
print(dic)
# Out:
# ['AAP.png', 'AITC.png', 'BJP.png', 'BSP.png', 'CPI(M).png', 'CPI.png', 'INC.jpg', 'NCP.png', 'NPP.png']
# {'AAP.png': b'...', 'AITC.png': b'...', 'BJP.png': b'...', 'BSP.png': b'...', 'CPI(M).png': b'...', 'CPI.png': b'...', 'INC.jpg': b'...', 'NCP.png': b'...', 'NPP.png': b'...'}

# %%
for items in dic:
    print(items)
# Out:
# AAP.png
# AITC.png
# BJP.png
# BSP.png
# CPI(M).png
# CPI.png
# INC.jpg
# NCP.png
# NPP.png

# %%
l=[]

for items in dic:
    d={}
    name=items.split('.')[0]
    print(name)
    d['img']=dic[items]
#     print(d)
    d['Abbreviation']=name
    if(name=='AAP'):
        d['Name']='Aam Aadmi Party'
    elif(name=='AITC'):
        d['Name']='All India Trinamool Congress'
    elif(name=='BJP'):
        d['Name']='Bharatiya Janata Party'
    elif(name=='BSP'):
        d['Name']='Bahujan Samaj Party'
    elif(name=='CPI'):
        d['Name']='Communist Party of India'
    elif(name=='CPI(M)'):
        d['Name']='Communist Party of India (Marxist)'
    elif(name=='INC'):
        d['Name']='Indian National Congress'
    elif(name=='NCP'):
        d['Name']='Nationalist Congress Party'
    elif(name=='NPP'):
        d['Name']='National People\'s Party'
    else:
        d['Name']='NOTA'
    l.append(d)
print(l)
# Out:
# AAP
# AITC
# BJP
# BSP
# CPI(M)
# CPI
# INC
# NCP
# NPP
# [{'img': b'...', 'Abbreviation': 'AAP', 'Name': 'Aam Aadmi Party'}, {'img': b'...', 'Abbreviation': 'AITC', 'Name': 'All India Trinamool Congress'}, {'img': b'...', 'Abbreviation': 'BJP', 'Name': 'Bharatiya Janata Party'}, {'img': b'...', 'Abbreviation': 'BSP', 'Name': 'Bahujan Samaj Party'}, {'img': b'...', 'Abbreviation': 'CPI(M)', 'Name': 'Communist Party of India (Marxist)'}, {'img': b'...', 'Abbreviation': 'CPI', 'Name': 'Communist Party of India'}, {'img': b'...', 'Abbreviation': 'INC', 'Name': 'Indian National Congress'}, {'img': b'...', 'Abbreviation': 'NCP', 'Name': 'Nationalist Congress Party'}, {'img': b'...', 'Abbreviation': 'NPP', 'Name': "National People's Party"}]

# %%
records.insert_many(l)

# %%
d1={}
d1['Name']='Others'
d1['Abbreviation']='Others'
d1['img']=None
records.insert_one(d1)

# %%
d2={}
d2['Name']='NOTA'
d2['Abbreviation']='NOTA'
d2['img']=None
records.insert_one(d2)
