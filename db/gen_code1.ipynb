# %%
import os, requests, uuid, json
from faker import Faker
from faker.providers import internet
import random
from pymongo import MongoClient 
from datetime import datetime, date

try:
    client = MongoClient("mongodb+srv://codefundo:codefundo@cluster0-qx5uu.azure.mongodb.net/test?retryWrites=true") 
    print(client)
    print("connection successfull!")
    # print(client)
except:
    print("connection not established")
db=client.get_database('codefundo')
records=db.voterId
print(records.count_documents({}))



def get_translation(text_input, language_output):
    base_url = 'https://api.cognitive.microsofttranslator.com'
    path = '/translate?api-version=3.0'
    params = '&to=' + language_output
    constructed_url = base_url + path + params

    headers = {
        'Ocp-Apim-Subscription-Key': 'ff58ef60bc734bf58cad41aac292f2f6',
        'Content-type': 'application/json',
        'X-ClientTraceId': str(uuid.uuid4())
    }
    print(text_input)
    # You can pass more than one object in body.
    body = [{
        'text' : text_input
    }]
    response = requests.post(constructed_url, headers=headers, json=body)
    return response.json()
# Out:
# MongoClient(host=['cluster0-shard-00-01-qx5uu.azure.mongodb.net:27017', 'cluster0-shard-00-00-qx5uu.azure.mongodb.net:27017', 'cluster0-shard-00-02-qx5uu.azure.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Cluster0-shard-0', ssl=True, retrywrites=True)
# connection successfull!
# 0

# %%
fake = Faker('hi_IN')
print(fake.__dict__)
# Out:
# {'providers': [<faker.providers.user_agent.Provider object at 0x000002425BC1E358>, <faker.providers.ssn.en_US.Provider object at 0x000002425BC1E2E8>, <faker.providers.python.Provider object at 0x000002425BC14EB8>, <faker.providers.profile.Provider object at 0x000002425BC14D30>, <faker.providers.phone_number.hi_IN.Provider object at 0x000002425BC14E48>, <faker.providers.person.hi_IN.Provider object at 0x000002425BC14DA0>, <faker.providers.misc.Provider object at 0x000002425BC14BE0>, <faker.providers.lorem.la.Provider object at 0x000002425BC14CC0>, <faker.providers.job.en_US.Provider object at 0x000002425BC11828>, <faker.providers.isbn.Provider object at 0x000002425BC112E8>, <faker.providers.internet.en_US.Provider object at 0x000002425BC11080>, <faker.providers.geo.en_US.Provider object at 0x0000024259EE6160>, <faker.providers.file.Provider object at 0x0000024259EE6278>, <faker.providers.date_time.en_US.Provider object at 0x0000024259EE6390>, <faker.providers.currency.Provider object 
# ...

# %%
ward_number=[]
for i in range(1,50):
    s=str(i)
    if(len(s)==1):
        s='00'+str(i)
    if(len(s)==2):
        s='0'+str(i)
        
    ward_number.append(s)
print(ward_number)

district_num=[]
for i in range(1,30):
    s=str(i)
    if(len(s)==1):
        s='00'+str(i)
    if(len(s)==2):
        s='0'+str(i)
        
    district_num.append(s)
print(district_num)
# Out:
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049']
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029']

# %%
string="mystring";
print(string[:-1])
# Out:
# mystrin

# %%
user=[]
for i in range(1000):
    p1 = fake.profile(fields=['name','sex','address','birthdate'])
    p1['name']=get_translation(p1['name'],'en')
    for item in p1['name']:
        p1['name']=item['translations'][0]['text']
    p1['address']=get_translation(p1['address'],'en')
    for item in p1['address']:
        p1['address']=item['translations'][0]['text']
    p1['birthdate']=p1['birthdate'].strftime('%d/%m/%Y')
    p1['password']=fake.password()
    fn = p1['name'].split(" ")
    print(fn)
    p1['father name']=''
    if(fn[0].endswith(',')):
        p1['father name']=fn[0][:-1]
        p1['username']=fn[1].lower()
    else:
        try:
            p1['father name']=fn[1]
            p1['username']=fn[0].lower()
        except:
            pass
    print(p1['father name'])
    print(type(p1['father name']))
    p1['ph_no']=fake.phone_number()
    p1['ward_num']=random.choice(ward_number)
    p1['district_num']=random.choice(district_num)
    p1['voter_id']=p1['ward_num']+'/'+p1['district_num']+'/'+str(random.randint(1,101))
#     records.insert_one(p1)
    user.append(p1)
print(user)
# Out:
# अवनी वफादार
# 46 विवेक गर्ग
# अन्तर्गत 917455
# ['Avani', 'Faithful']
# Faithful
# <class 'str'>
# अजित लोदी
# 5/0 प्रणव ढींगरा
# बचेली-209304
# ['Ajit', 'Lodi']
# Lodi
# <class 'str'>
# बसु, अनुपम
# 81/766 आशा महादेव
# अमरोहा-483678
# ['Basu,', 'Anupam']
# Basu
# <class 'str'>
# कुमार, रिया
# 10/1828 दत्ता
# दालखोला-264501
# ['Kumar,', 'Ria']
# Kumar
# <class 'str'>
# दत्ता, अंकुर
# 823 दादा
# अलीगढ-519283
# ['Dutta,', 'Ankur']
# Dutta
# <class 'str'>
# नरेन्द्र कुलकर्णी
# 8 कृष्णा
# धारवाड-304493
# ['Narendra', 'Kulkarni']
# Kulkarni
# <class 'str'>
# श्रीविमल, रचना
# 2 तृष्णा लोदी
# चंबा 308587
# ['Srivimal,', 'Creation']
# Srivimal
# <class 'str'>
# सरला गणेश
# 89 मगर
# अन्तर्गत 442367
# ['Sarla', 'Ganesh']
# Ganesh
# <class 'str'>
# अखिल दादा
# 53 अमर मंगल
# मोकामा 105861
# ['All-Dada']
#
# <class 'str'>
# दारा, अंकुर
# 84/6282 विक्रम दीक्षित
# आदिलाबाद 495803
# ['Darius,', 'Ankur']
# Darius
# <class 'str'>
# अंकिता ढींगरा
# 747 सरला सिंह
# चित्रकूट-934953
# ...

# %%
import json

with open('test.txt', 'w') as f:
#     f.write(json.dumps(translated_list))
    f.writelines( "%s\n" % item for item in user )

# %%
import string
import secrets
for item in user:
#     print(item['voter_id'])
    item['voter_id']=''.join(secrets.choice(string.ascii_uppercase) for _ in range(3))+''.join(secrets.choice(string.digits) for _ in range(7))

# %%
import json

with open('test1.txt', 'w') as f:
#     f.write(json.dumps(translated_list))
    f.writelines( "%s\n" % item for item in user )

# %%
print(len(user))
# Out:
# 1000

# %%
records.insert_many(user)
